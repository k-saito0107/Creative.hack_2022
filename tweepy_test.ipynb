# %%
import tweepy
from pprint import pprint
import datetime

# API情報を記入
BEARER_TOKEN        = "AAAAAAAAAAAAAAAAAAAAAI2ZkQEAAAAApqf9Rgly0Q0D7e2MuJymIZbkf4Q%3DNy1OuUAPsr2ZzwyWqli7U9LWmCdtKtwaIuUfSeA9rXKIK5FhOB"
API_KEY             = "6vV9WJJgIYvwhESJZfoURqdGQ"
API_SECRET          = "xM2odKcWj1e8Pw3RtFqgzM8cCXzLGoRSc2bwQXwPmTTEiqvkd3"
ACCESS_TOKEN        = "1602666678113906688-mQI7NDdbQa7E7e0oM1BcegkF2ynG73"
ACCESS_TOKEN_SECRET = "dZM276IlRF3JaNtGoXlSYAQPPIdrkYAtjxGVEugZFbn5e"


# クライアント関数を作成
def ClientInfo():
    client = tweepy.Client(bearer_token    = BEARER_TOKEN,
                           consumer_key    = API_KEY,
                           consumer_secret = API_SECRET,
                           access_token    = ACCESS_TOKEN,
                           access_token_secret = ACCESS_TOKEN_SECRET,
                          )
    
    return client

# %%
# 実行時時刻
print("**********  実行日時："+datetime.datetime.now().strftime('%Y/%m/%d %H:%M')        +"  **********")

# ★必要情報入力
search    = "Python学習"  # 検索対象
tweet_max = 10           # 取得したいツイート数(10〜100で設定可能)

# 関数
def SearchTweets(search,tweet_max):    
    # 直近のツイート取得
    tweets = ClientInfo().search_recent_tweets(query = search, max_results = tweet_max)

    # 取得したデータ加工
    results     = []
    tweets_data = tweets.data

    # tweet検索結果取得
    if tweets_data != None:
        for tweet in tweets_data:
            obj = {}
            obj["tweet_id"] = tweet.id      # Tweet_ID
            obj["text"] = tweet.text  # Tweet Content
            results.append(obj)
    else:
        results.append('')

    # 結果出力
    return results

# 関数実行・出力
pprint(SearchTweets(search,tweet_max))
# Out:
# **********  実行日時：2022/12/28 21:01  **********
# [{'text': '連休初日ガッツリ積み上げできました😊\n'
#           '\n'
#           '旅行も帰省もショッピングの予定も無い連休だけど、その分自己研鑽に励みますよ😌\n'
#           '\n'
#           '今日の結果\n'
#           '➡️読書 2:30\n'
#           '➡️ブログ執筆 2件\n'
#           '➡️Python学習 0:30\n'
#           '➡️資格試験学習 5:15\n'
#           '➡️ジョギング 20km\n'
#           '\n'
#           '#今日の積み上げ結果',
#   'tweet_id': 1608063539067121664},
#  {'text': '@pukusaan Python学習仲間が欲しいのでフォローさせていただきました！\n'
#           '\n'
#           'いきなり素朴な疑問なのですが、、、\n'
#           '\n'
#           '腕立て伏せの回数が63回というのは何か意味があるのでしょうか？？',
#   'tweet_id': 1607997859785506817},
#  {'text': '「Python 学習レッスン I」コースを修了しました！ https://t.co/IdbQw8Ti0a #Progate',
#   'tweet_id': 1607954241355931649},
#  {'text': '順調\n「Python 学習レッスン I」コースを修了しました！ https://t.co/sxr0atLN6I #Progate',
#   'tweet_id': 1607948057307643907},
#  {'text': 'RT @superbeatclub: おはようございます！\n'
#           '今朝は2時半に起きて読書＆勉強📚\n'
#           '\n'
#           'さぁ今日連休スタートです✨\n'
#           '\n'
#           '全く予定無いけど時間はたっぷりあるので、連休もたっぷり積み上よう😊\n'
#           '\n'
#           '今日の予定\n'
#           '➡️読書 2:30\n'
#           '➡️ブログ執筆 2件\n'
#           '➡️Python学習 0:3…',
#   'tweet_id': 1607941166116540417},
#  {'text': '@Halu_lento 遊ぶついでとPython学習程度にしか触ってねぇや(:3_ヽ)_',
#   'tweet_id': 1607927159099920387},
#  {'text': '「Python 学習レッスン IV」コースを修了しました！ https://t.co/mxqqy3tQIO #Progate',
#   'tweet_id': 1607903723736698880},
#  {'text': 'RT @baku2san: 今日もPython学習しましょう！\n'
#           '#paizaラーニング #今日の積み上げ #プログラミング\n'
#           '\n'
#           'PickUp!\n'
#           'Have you heard about #PowerPlatform? Power Platform is a '
#           'collection…',
#   'tweet_id': 1607861767014678528},
#  {'text': '今日もPython学習しましょう！\n'
#           '#paizaラーニング #今日の積み上げ #プログラミング\n'
#           '\n'
#           'PickUp!\n'
#           'Have you heard about #PowerPlatform? Power Platform is a collection '
#           'of four different applications #PowerBI, #PowerAutomate, '
#           '#PowerApps, and #PowerVirtualAgents that work with all your #data '
#           'so',
#   'tweet_id': 1607856602962624512},
#  {'text': 'RT @uotanino: 今日含めて残り4日だ😳□白湯□モーニングページ□プロテイン□課題□お散歩駆け出しエンジニアと繋がりたい '
#           'yuinyan_bishoujoおはようございます。\n'
#           '朝活開始！・Python学習・基礎英文法朝 #駆け出しエンジニアと繋がりたい #今日の積み上げ',
#   'tweet_id': 1607854753475698688}]
